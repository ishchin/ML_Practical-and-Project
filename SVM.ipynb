# %%
import pandas as pd

# %%
data=pd.read_csv("bill.csv")

# %%
data.head()
# Out:
#    Variance  Skewness  Curtosis  Entropy  Class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
data.shape
# Out:
# (1372, 5)

# %%
x=data.drop('Class',axis=1)

# %%
print(x)
# Out:
#       Variance  Skewness  Curtosis  Entropy
# 0      3.62160   8.66610   -2.8073 -0.44699
# 1      4.54590   8.16740   -2.4586 -1.46210
# 2      3.86600  -2.63830    1.9242  0.10645
# 3      3.45660   9.52280   -4.0112 -3.59440
# 4      0.32924  -4.45520    4.5718 -0.98880
# ...        ...       ...       ...      ...
# 1367   0.40614   1.34920   -1.4501 -0.55949
# 1368  -1.38870  -4.87730    6.4774  0.34179
# 1369  -3.75030 -13.45860   17.5932 -2.77710
# 1370  -3.56370  -8.38270   12.3930 -1.28230
# 1371  -2.54190  -0.65804    2.6842  1.19520
#
# [1372 rows x 4 columns]

# %%
y=data['Class']

# %%
print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1367    1
# 1368    1
# 1369    1
# 1370    1
# 1371    1
# Name: Class, Length: 1372, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
from sklearn.svm import SVC 
classifier =SVC(kernel='linear')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_predict=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[142   2]
#  [  4 127]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       144
#            1       0.98      0.97      0.98       131
#
#     accuracy                           0.98       275
#    macro avg       0.98      0.98      0.98       275
# weighted avg       0.98      0.98      0.98       275

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %%
from sklearn.svm import SVC 
classifier =SVC(kernel='linear')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_predict=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[235   4]
#  [  3 170]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       239
#            1       0.98      0.98      0.98       173
#
#     accuracy                           0.98       412
#    macro avg       0.98      0.98      0.98       412
# weighted avg       0.98      0.98      0.98       412

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.40)

# %%
from sklearn.svm import SVC 
classifier =SVC(kernel='linear')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_predict=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[296   5]
#  [  1 247]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       301
#            1       0.98      1.00      0.99       248
#
#     accuracy                           0.99       549
#    macro avg       0.99      0.99      0.99       549
# weighted avg       0.99      0.99      0.99       549

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35)

# %%
from sklearn.svm import SVC 
classifier =SVC(kernel='linear')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_predict=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[272   3]
#  [  1 205]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       275
#            1       0.99      1.00      0.99       206
#
#     accuracy                           0.99       481
#    macro avg       0.99      0.99      0.99       481
# weighted avg       0.99      0.99      0.99       481

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
from sklearn.svm import SVC 
classifier =SVC(kernel='rbf')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_predict=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[151   2]
#  [  0 122]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       153
#            1       0.98      1.00      0.99       122
#
#     accuracy                           0.99       275
#    macro avg       0.99      0.99      0.99       275
# weighted avg       0.99      0.99      0.99       275

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %%
from sklearn.svm import SVC 
classifier =SVC(kernel='rbf')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_predict=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[225   1]
#  [  0 186]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       226
#            1       0.99      1.00      1.00       186
#
#     accuracy                           1.00       412
#    macro avg       1.00      1.00      1.00       412
# weighted avg       1.00      1.00      1.00       412

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35)

# %%
from sklearn.svm import SVC 
classifier =SVC(kernel='rbf')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_predict=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[274   0]
#  [  0 207]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       274
#            1       1.00      1.00      1.00       207
#
#     accuracy                           1.00       481
#    macro avg       1.00      1.00      1.00       481
# weighted avg       1.00      1.00      1.00       481

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.40)

# %%
from sklearn.svm import SVC 
classifier =SVC(kernel='rbf')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_predict=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[314   3]
#  [  0 232]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       317
#            1       0.99      1.00      0.99       232
#
#     accuracy                           0.99       549
#    macro avg       0.99      1.00      0.99       549
# weighted avg       0.99      0.99      0.99       549

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
from sklearn.svm import SVC 
classifier =SVC(kernel='sigmoid')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_predict=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[114  39]
#  [ 59  63]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.75      0.70       153
#            1       0.62      0.52      0.56       122
#
#     accuracy                           0.64       275
#    macro avg       0.64      0.63      0.63       275
# weighted avg       0.64      0.64      0.64       275

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %%
from sklearn.svm import SVC 
classifier =SVC(kernel='sigmoid')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_predict=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[152  75]
#  [ 74 111]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67       227
#            1       0.60      0.60      0.60       185
#
#     accuracy                           0.64       412
#    macro avg       0.63      0.63      0.63       412
# weighted avg       0.64      0.64      0.64       412

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35)

# %%
from sklearn.svm import SVC 
classifier =SVC(kernel='sigmoid')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_predict=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[190  88]
#  [ 61 142]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.68      0.72       278
#            1       0.62      0.70      0.66       203
#
#     accuracy                           0.69       481
#    macro avg       0.69      0.69      0.69       481
# weighted avg       0.70      0.69      0.69       481

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.40)

# %%
from sklearn.svm import SVC 
classifier =SVC(kernel='sigmoid')

# %%
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_predict=classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[206 100]
#  [ 88 155]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.67      0.69       306
#            1       0.61      0.64      0.62       243
#
#     accuracy                           0.66       549
#    macro avg       0.65      0.66      0.65       549
# weighted avg       0.66      0.66      0.66       549
